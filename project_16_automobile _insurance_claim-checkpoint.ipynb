# %%
## dataset   =====  ##  predicting the claim amount in the Automobile insurance dataset

##task 1

# %%
# IMPORTING LIBRARIES  
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings 
warnings.filterwarnings('ignore')
# Out:
# C:\Users\prince\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\Users\prince\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\Users\prince\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\Users\prince\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
data=pd.read_csv("claim amount.csv")
##  predicting the claim amount in the Automobile insurance dataset

# %%
data.head()
# Out:
#   Customer Country State Code     State  Claim Amount Response  Coverage  \
# 0  BU79786      US         KS    Kansas    276.351928       No     Basic
# 1  QZ44356      US         NE  Nebraska    697.953590       No  Extended
# 2  AI49188      US         OK  Oklahoma   1288.743165       No   Premium
# 3  WW63253      US         MO  Missouri    764.586183       No     Basic
# 4  HB64268      US         KS    Kansas    281.369258       No     Basic
#
#   Education Effective To Date EmploymentStatus  ...  \
# 0  Bachelor           2/24/11         Employed  ...
# 1  Bachelor           1/31/11       Unemployed  ...
# 2  Bachelor           2/19/11         Employed  ...
# 3  Bachelor           1/20/11       Unemployed  ...
# 4  Bachelor            2/3/11         Employed  ...
#
#   Months Since Policy Inception  Number of Open Complaints Number of Policies  \
# 0                             5                          0                  1
# ...

# %%
data.shape
# 9134 rows * 26 columns
# Out:
# (9134, 26)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 26 columns):
# Customer                         9134 non-null object
# Country                          9134 non-null object
# State Code                       9134 non-null object
# State                            9134 non-null object
# Claim Amount                     9134 non-null float64
# Response                         9134 non-null object
# Coverage                         9134 non-null object
# Education                        9134 non-null object
# Effective To Date                9134 non-null object
# EmploymentStatus                 9134 non-null object
# Gender                           9134 non-null object
# Income                           9134 non-null int64
# Location Code                    9134 non-null object
# Marital Status                   9134 non-null object
# Monthly Premium Auto             9134 non-null int64
# ...

# %%
data.dtypes
# Out:
# Customer                          object
# Country                           object
# State Code                        object
# State                             object
# Claim Amount                     float64
# Response                          object
# Coverage                          object
# Education                         object
# Effective To Date                 object
# EmploymentStatus                  object
# Gender                            object
# Income                             int64
# Location Code                     object
# Marital Status                    object
# Monthly Premium Auto               int64
# Months Since Last Claim            int64
# Months Since Policy Inception      int64
# Number of Open Complaints          int64
# Number of Policies                 int64
# Policy Type                       object
# Policy                            object
# Claim Reason                      object
# Sales Channel                     object
# ...

# %%
print(data.isnull().sum())
print(sns.heatmap(data.isnull()))

## nullvalues for dataset
# no null values
# Out:
# Customer                         0
# Country                          0
# State Code                       0
# State                            0
# Claim Amount                     0
# Response                         0
# Coverage                         0
# Education                        0
# Effective To Date                0
# EmploymentStatus                 0
# Gender                           0
# Income                           0
# Location Code                    0
# Marital Status                   0
# Monthly Premium Auto             0
# Months Since Last Claim          0
# Months Since Policy Inception    0
# Number of Open Complaints        0
# Number of Policies               0
# Policy Type                      0
# Policy                           0
# Claim Reason                     0
# Sales Channel                    0
# Total Claim Amount               0
# Vehicle Class                    0
# Vehicle Size                     0
# dtype: int64
# ...

# %%
## correlation in dataset

print(data.corr())
print(sns.heatmap(data.corr()))
# Out:
#                                Claim Amount    Income  Monthly Premium Auto  \
# Claim Amount                       1.000000  0.024366              0.396262
# Income                             0.024366  1.000000             -0.016665
# Monthly Premium Auto               0.396262 -0.016665              1.000000
# Months Since Last Claim            0.011517 -0.026715              0.005026
# Months Since Policy Inception      0.009418 -0.000875              0.020257
# Number of Open Complaints         -0.036343  0.006408             -0.013122
# Number of Policies                 0.021955 -0.008656             -0.011233
# Total Claim Amount                 0.226451 -0.355254              0.632017
#
#                                Months Since Last Claim  \
# Claim Amount                                  0.011517
# Income                                       -0.026715
# Monthly Premium Auto                          0.005026
# Months Since Last Claim                       1.000000
# ...

# %%
data.describe()
# Out:
#        Claim Amount        Income  Monthly Premium Auto  \
# count   9134.000000   9134.000000           9134.000000
# mean     800.494047  37657.380009             93.219291
# std      687.096761  30379.904734             34.407967
# min      189.800768      0.000000             61.000000
# 25%      399.425179      0.000000             68.000000
# 50%      578.018220  33889.500000             83.000000
# 75%      896.216704  62320.000000            109.000000
# max     8332.538119  99981.000000            298.000000
#
#        Months Since Last Claim  Months Since Policy Inception  \
# count              9134.000000                    9134.000000
# mean                 15.097000                      48.064594
# std                  10.073257                      27.905991
# min                   0.000000                       0.000000
# 25%                   6.000000                      24.000000
# 50%                  14.000000                      48.000000
# ...

# %%
data.hist(figsize=(10,15))
plt.show()

# %%
sns.distplot(data['Claim Amount'])

# %%
sns.scatterplot(data['Claim Amount'],data['Total Claim Amount'])

# %%
sns.barplot(x=data['Number of Open Complaints'],y=data['Claim Amount'])

# %%
sns.barplot(x=data['Number of Policies'],y=data['Claim Amount'])

## 2 polices being have the highest claim amount
#  1 being the lowest amounts

# %%
sns.barplot(x=data['Policy Type'],y=data['Claim Amount'])

# %%
sns.barplot(x=data['Claim Reason'],y=data['Claim Amount'])

# %%
sns.countplot(data['Claim Reason'])

# %%
sns.violinplot(x=data['Sales Channel'],y=data['Claim Amount'])

# %%
sns.countplot(data['Sales Channel'])
## agents being the most and web being the lowest in sales for the automobiles

# %%
sns.violinplot(x=data['Vehicle Class'],y=data['Claim Amount'])

## luxury class have higher claim amount

# %%
sns.countplot(data['Vehicle Class'])
# luxury suv being the lowest and 4 door being the highest

# %%
sns.violinplot(x=data['Vehicle Size'],y=data['Claim Amount'])

# %%
sns.countplot(data['Vehicle Size'])

## medium size cars being the most

# %%
plt.figure(figsize=(10,5))
sns.barplot(x=data['Policy'],y=data['Claim Amount'])

# %%
plt.figure(figsize=(10,4))
sns.countplot(data['Policy'])

# %%
plt.figure(figsize=(10,5))
sns.violinplot(x=data['EmploymentStatus'],y=data['Claim Amount'])

# %%
sns.countplot(data['EmploymentStatus'])

# %%
plt.figure(figsize=(10,5))
sns.violinplot(x=data['Education'],y=data['Claim Amount'])

# %%
sns.countplot(data['Education'])

# %%
plt.figure(figsize=(10,5))
sns.violinplot(x=data['Coverage'],y=data['Claim Amount'])

# %%
sns.countplot(data['Coverage'])

# %%
plt.figure(figsize=(10,5))
sns.violinplot(x=data['Marital Status'],y=data['Claim Amount'])

# %%
sns.countplot(data['Marital Status'])

# %%
sns.barplot(data['Gender'],data['Claim Amount'])

# %%
sns.scatterplot(data['Income'],data['Claim Amount'])

# %%
sns.kdeplot(data['Income'],data['Claim Amount'],shade=True)

# %%
sns.kdeplot(data['Total Claim Amount'],data['Claim Amount'],shade=True)

# %%
sns.pairplot(data)

# %%
data.skew()  ## checking the skewness
# Out:
# Claim Amount                     3.032280
# Income                           0.286887
# Monthly Premium Auto             2.123546
# Months Since Last Claim          0.278586
# Months Since Policy Inception    0.040165
# Number of Open Complaints        2.783263
# Number of Policies               1.253333
# Total Claim Amount               1.714966
# dtype: float64

# %%
## removing the skewness

data['Monthly Premium Auto']=np.log1p(data['Monthly Premium Auto'])
data['Total Claim Amount']=np.log1p(data['Total Claim Amount'])
data['Claim Amount']=np.log1p(data['Claim Amount'])

# %%
data.skew() ## removed
# Out:
# Claim Amount                     0.578248
# Income                           0.286887
# Monthly Premium Auto             1.013663
# Months Since Last Claim          0.278586
# Months Since Policy Inception    0.040165
# Number of Open Complaints        2.783263
# Number of Policies               1.253333
# Total Claim Amount              -1.741369
# dtype: float64

# %%
data.hist(figsize=(15,15))
plt.show()

# %%
## importing the label encoder for conversion of dataset into int  or float dtype
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
data["Education"] = le.fit_transform(data["Education"])
data["EmploymentStatus"] = le.fit_transform(data["EmploymentStatus"])
data["Gender"] = le.fit_transform(data["Gender"])
data["Marital Status"] = le.fit_transform(data["Marital Status"])
data["Policy Type"] = le.fit_transform(data["Policy Type"])
data["State"] = le.fit_transform(data["State"])
data["Country"] = le.fit_transform(data["Country"])
data["Coverage"] = le.fit_transform(data["Coverage"])
data["Location"] = le.fit_transform(data["Location Code"])
data["Response"] = le.fit_transform(data["Response"])
data["Vehicle Size"] = le.fit_transform(data["Vehicle Size"])
data["Sales Channel"] = le.fit_transform(data["Sales Channel"])

# %%
data.dtypes
# Out:
# Customer                          object
# Country                            int32
# State Code                        object
# State                              int32
# Claim Amount                     float64
# Response                           int32
# Coverage                           int32
# Education                          int32
# Effective To Date                 object
# EmploymentStatus                   int32
# Gender                             int32
# Income                             int64
# Location Code                     object
# Marital Status                     int32
# Monthly Premium Auto             float64
# Months Since Last Claim            int64
# Months Since Policy Inception      int64
# Number of Open Complaints          int64
# Number of Policies                 int64
# Policy Type                        int32
# Policy                            object
# Claim Reason                      object
# Sales Channel                      int32
# ...

# %%
df=data.drop(['Customer','State Code','Effective To Date','Location Code'],axis=1)

# %%
df
# Out:
#       Country  State  Claim Amount  Response  Coverage  Education  \
# 0           0      1      5.625287         0         0          0
# 1           0      3      6.549584         0         1          0
# 2           0      4      7.162198         0         2          0
# 3           0      2      6.640642         0         0          0
# 4           0      1      5.643216         0         0          0
# ...       ...    ...           ...       ...       ...        ...
# 9129        0      2      7.758589         0         0          0
# 9130        0      2      5.738670         1         1          1
# 9131        0      2      6.706115         0         1          0
# 9132        0      2      6.624655         0         1          1
# 9133        0      2      5.569045         0         1          1
#
#       EmploymentStatus  Gender  Income  Marital Status  ...  \
# 0                    1       0   56274               1  ...
# ...

# %%
df['Policy'].nunique()
# Out:
# 9

# %%
df['Claim Reason'].nunique()
# Out:
# 4

# %%
df['Vehicle Class'].nunique()
# Out:
# 6

# %%
df= pd.get_dummies(data=df, columns=["Policy","Claim Reason","Vehicle Class"])
df.head()
# Out:
#    Country  State  Claim Amount  Response  Coverage  Education  \
# 0        0      1      5.625287         0         0          0
# 1        0      3      6.549584         0         1          0
# 2        0      4      7.162198         0         2          0
# 3        0      2      6.640642         0         0          0
# 4        0      1      5.643216         0         0          0
#
#    EmploymentStatus  Gender  Income  Marital Status  ...  \
# 0                 1       0   56274               1  ...
# 1                 4       0       0               2  ...
# 2                 1       0   48767               1  ...
# 3                 4       1       0               1  ...
# 4                 1       1   43836               2  ...
#
#    Claim Reason_Collision  Claim Reason_Hail  Claim Reason_Other  \
# 0                       1                  0                   0
# 1                       0                  0                   0
# ...

# %%
df.dtypes
# Out:
# Country                            int32
# State                              int32
# Claim Amount                     float64
# Response                           int32
# Coverage                           int32
# Education                          int32
# EmploymentStatus                   int32
# Gender                             int32
# Income                             int64
# Marital Status                     int32
# Monthly Premium Auto             float64
# Months Since Last Claim            int64
# Months Since Policy Inception      int64
# Number of Open Complaints          int64
# Number of Policies                 int64
# Policy Type                        int32
# Sales Channel                      int32
# Total Claim Amount               float64
# Vehicle Size                       int32
# Location                           int32
# Policy_Corporate L1                uint8
# Policy_Corporate L2                uint8
# Policy_Corporate L3                uint8
# ...

# %%
## removing the outliers
from scipy.stats import zscore
z=np.abs(zscore(df))
df1=df[(z<3).all(axis=1)]

# %%
df
# Out:
#       Country  State  Claim Amount  Response  Coverage  Education  \
# 0           0      1      5.625287         0         0          0
# 1           0      3      6.549584         0         1          0
# 2           0      4      7.162198         0         2          0
# 3           0      2      6.640642         0         0          0
# 4           0      1      5.643216         0         0          0
# ...       ...    ...           ...       ...       ...        ...
# 9129        0      2      7.758589         0         0          0
# 9130        0      2      5.738670         1         1          1
# 9131        0      2      6.706115         0         1          0
# 9132        0      2      6.624655         0         1          1
# 9133        0      2      5.569045         0         1          1
#
#       EmploymentStatus  Gender  Income  Marital Status  ...  \
# 0                    1       0   56274               1  ...
# ...

# %%
x=df.drop('Claim Amount',axis=1)## features
y=df['Claim Amount']## target

# %%
x.head()
# Out:
#    Country  State  Response  Coverage  Education  EmploymentStatus  Gender  \
# 0        0      1         0         0          0                 1       0
# 1        0      3         0         1          0                 4       0
# 2        0      4         0         2          0                 1       0
# 3        0      2         0         0          0                 4       1
# 4        0      1         0         0          0                 1       1
#
#    Income  Marital Status  Monthly Premium Auto  ...  Claim Reason_Collision  \
# 0   56274               1              4.248495  ...                       1
# 1       0               2              4.553877  ...                       0
# 2   48767               1              4.691348  ...                       1
# 3       0               1              4.672829  ...                       1
# 4   43836               2              4.304065  ...                       1
#
# ...

# %%
y.head()
# Out:
# 0    5.625287
# 1    6.549584
# 2    7.162198
# 3    6.640642
# 4    5.643216
# Name: Claim Amount, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
x=ss.fit_transform(x) ## standard scaling the dataset

# %%
## importing the metrics and other models
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier,AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split,cross_val_score,GridSearchCV
from sklearn.metrics import r2_score,mean_squared_error,mean_squared_error,mean_absolute_error

# %%
# CREATING A FUNCTION FOR FINDING OUT THE BEST RANDOM STATE HAVING THE MAX r SCORE 
def maxr2_Score(regr,x,y):
    max_r_score=0
    for r_state in range(42,101):
        x_train, x_test, y_train, y_test=train_test_split(x,y,random_state=r_state,test_size=0.22)
        regr.fit(x_train,y_train)
        y_pred=regr.predict(x_test)
        r2_scr=r2_score(y_test,y_pred)
        print('r2_score corr to random state',r_state,'is:',r2_scr)
        if r2_scr>max_r_score:
            max_r_score=r2_scr
            final_r_state=r_state
    print()
    print()
    print("max r2 score corr to ",final_r_state,'is',max_r_score)       
    return final_r_state

# %%
# FINDING  BEST RANDOM STATE FOR LINEAR REG WITH HIGH R SCORE
from sklearn.linear_model import LinearRegression
lreg=LinearRegression()
r_state=maxr2_Score(lreg,x,y)
# Out:
# r2_score corr to random state 42 is: 0.26104485698403
# r2_score corr to random state 43 is: 0.2714520783440786
# r2_score corr to random state 44 is: 0.25728888723009513
# r2_score corr to random state 45 is: 0.26022372956170825
# r2_score corr to random state 46 is: 0.2643936501140275
# r2_score corr to random state 47 is: 0.2867577950100828
# r2_score corr to random state 48 is: 0.27293143997846636
# r2_score corr to random state 49 is: 0.2519437287407461
# r2_score corr to random state 50 is: 0.2754403410542323
# r2_score corr to random state 51 is: 0.21241617401265656
# r2_score corr to random state 52 is: 0.2750989406160719
# r2_score corr to random state 53 is: 0.2548774898912486
# r2_score corr to random state 54 is: 0.2516048924642088
# r2_score corr to random state 55 is: 0.2829585259799636
# r2_score corr to random state 56 is: 0.2606464503403507
# r2_score corr to random state 57 is: 0.2630574533344455
# r2_score corr to random state 58 is: 0.2526088039989133
# ...

# %%
# IMPORTING PCA FOR FINDING BEST CORRELATED COLUMNS
from sklearn.decomposition import PCA
pca = PCA(n_components=20)
x_new=pca.fit_transform(x)

# %%
def maxr2_Score(regr,x_new,y):
    max_r_score=0
    for r_state in range(42,101):
        x_train, x_test, y_train, y_test=train_test_split(x_new,y,random_state=r_state,test_size=0.22)
        regr.fit(x_train,y_train)
        y_pred=regr.predict(x_test)
        r2_scr=r2_score(y_test,y_pred)
        print('r2_score corr to random state',r_state,'is:',r2_scr)
        if r2_scr>max_r_score:
            max_r_score=r2_scr
            final_r_state=r_state
    print()
    print()
    print("max r2 score corr to ",final_r_state,'is',max_r_score)       
    return final_r_state

# %%
from sklearn.linear_model import LinearRegression
lreg=LinearRegression()
r_state=maxr2_Score(lreg,x_new,y)
# Out:
# r2_score corr to random state 42 is: 0.24181501861200272
# r2_score corr to random state 43 is: 0.2476698111542016
# r2_score corr to random state 44 is: 0.23193846158151976
# r2_score corr to random state 45 is: 0.24291792155076553
# r2_score corr to random state 46 is: 0.25260529114614294
# r2_score corr to random state 47 is: 0.2636713060951238
# r2_score corr to random state 48 is: 0.2516533915612851
# r2_score corr to random state 49 is: 0.22169477641897073
# r2_score corr to random state 50 is: 0.25188219640771337
# r2_score corr to random state 51 is: 0.20129933354811813
# r2_score corr to random state 52 is: 0.2681547489479271
# r2_score corr to random state 53 is: 0.2389423434722271
# r2_score corr to random state 54 is: 0.23208439344431642
# r2_score corr to random state 55 is: 0.26048866643670776
# r2_score corr to random state 56 is: 0.23647316257530748
# r2_score corr to random state 57 is: 0.2433021164232676
# r2_score corr to random state 58 is: 0.22756296675419718
# ...

# %%
# ON usinG pca we are getting bad results as before using pca 
# therefore dropping the method of using the PCA

# %%
#random state max r2 score corr to  89 is 
x_train,x_test,y_train,y_test=train_test_split(x_new,y,random_state=84,test_size=0.22)
lr=LinearRegression()
lr.fit(x_train,y_train)
ylreg=lr.predict(x_test)
print(lr.score(x_test, y_test)*100)
print(mean_squared_error(ylreg, y_test))
print(mean_absolute_error(ylreg, y_test))
print(cross_val_score(lreg,x,y,cv=5,scoring="r2").mean())
print(r2_score(y_test,ylreg))
# Out:
# 27.49014831883564
# 0.3231229500391047
# 0.43244683606513545
# 0.25921604007917987
# 0.2749014831883564

# %%
from sklearn.neighbors import KNeighborsRegressor
knn=KNeighborsRegressor()
parameters={'n_neighbors':[i+1 for i in range(10)]}
clf=GridSearchCV(knn,parameters)
clf.fit(x,y)
clf.best_params_
# Out:
# {'n_neighbors': 10}

# %%
#finding best rstate and rscore for knn 
knn=KNeighborsRegressor(n_neighbors=10)
r_state=maxr2_Score(knn,x,y)
# Out:
# r2_score corr to random state 42 is: 0.1990078826079571
# r2_score corr to random state 43 is: 0.19406099576267066
# r2_score corr to random state 44 is: 0.1675578024001727
# r2_score corr to random state 45 is: 0.17919015515395564
# r2_score corr to random state 46 is: 0.1989299796758488
# r2_score corr to random state 47 is: 0.19659864005324756
# r2_score corr to random state 48 is: 0.18635505915189998
# r2_score corr to random state 49 is: 0.1814314986577803
# r2_score corr to random state 50 is: 0.17891250256494529
# r2_score corr to random state 51 is: 0.15472834851916595
# r2_score corr to random state 52 is: 0.1880326037275799
# r2_score corr to random state 53 is: 0.18559929295435862
# r2_score corr to random state 54 is: 0.18958257620535335
# r2_score corr to random state 55 is: 0.21793198618713194
# r2_score corr to random state 56 is: 0.19117780648020033
# r2_score corr to random state 57 is: 0.18296612811673119
# r2_score corr to random state 58 is: 0.150006635433394
# ...

# %%
# RANDOM FORESST REGRESSOR
from sklearn.ensemble import RandomForestRegressor
rfr=RandomForestRegressor()
parameters={'n_estimators':[1,10,50,100,200,300,400,500,1000]}
clfr=GridSearchCV(rfr,parameters)
clfr.fit(x,y)
clfr.best_params_
# Out:
# {'n_estimators': 1000}

# %%
rfr = RandomForestRegressor(n_estimators = 1000)
r_state=maxr2_Score(rfr,x,y)
# Out:
# r2_score corr to random state 42 is: 0.9123675648657148
# r2_score corr to random state 43 is: 0.9167763298378405
# r2_score corr to random state 44 is: 0.9050449273616116
# r2_score corr to random state 45 is: 0.9147829541637282
# r2_score corr to random state 46 is: 0.9082460450839944
# r2_score corr to random state 47 is: 0.918056523891799
# r2_score corr to random state 48 is: 0.9115978659480338
# r2_score corr to random state 49 is: 0.9113804721758183
# r2_score corr to random state 50 is: 0.9099394894251659
# r2_score corr to random state 51 is: 0.9032226343791305
# r2_score corr to random state 52 is: 0.9067558911960002
# r2_score corr to random state 53 is: 0.9042161239774359
# r2_score corr to random state 54 is: 0.9064581003342088
# r2_score corr to random state 55 is: 0.9150395351069325
# r2_score corr to random state 56 is: 0.9063132923719583
# r2_score corr to random state 57 is: 0.9107892025363462
# r2_score corr to random state 58 is: 0.9133535817039203
# ...

# %%
######  Grid search for finding the best parameters and tuning them

# %%
## SVR FROM SUPPORT VECTOR MACHINE
from sklearn.svm import SVR
svr=SVR()
para_grid={'kernel':['poly','rbf','linear']}
clf_svr=GridSearchCV(svr,para_grid)
clf_svr.fit(x,y)
clf_svr.best_params_
# Out:
# {'kernel': 'rbf'}

# %%
from sklearn.ensemble import AdaBoostRegressor, GradientBoostingRegressor

# %%
# ADA boost regressor
ada=AdaBoostRegressor()
parameters={'n_estimators':[1,10,50,100,200,300,400,500,1000],'learning_rate':[0.001,0.01,0.1,1]}
clfr=GridSearchCV(ada,parameters)
clfr.fit(x,y)
clfr.best_params_
# Out:
# {'learning_rate': 0.1, 'n_estimators': 200}

# %%
# gradient boosting regressor
gbr=GradientBoostingRegressor()
parameters={'n_estimators':[1,10,50,100,200,300,400,500,1000],'learning_rate':[0.001,0.01,0.1,1]}
clfr=GridSearchCV(gbr,parameters)
clfr.fit(x,y)
clfr.best_params_
# Out:
# {'learning_rate': 0.1, 'n_estimators': 300}

# %%
## tuning the parammeters
from sklearn.tree import DecisionTreeRegressor
rfr=RandomForestRegressor(n_estimators=1000)
knn=KNeighborsRegressor(n_neighbors=10)
svr=SVR(kernel='rbf')
ada=AdaBoostRegressor(learning_rate=0.1,n_estimators=200)
gbr=GradientBoostingRegressor(learning_rate=0.1,n_estimators=300)
dtr=DecisionTreeRegressor()
lr=LinearRegression()

# %%
models = []
models.append(('randomforestREG', rfr))
models.append(('kneighborsREG', knn))
models.append(('svR', svr))
models.append(('ada boost REG', ada))
models.append(('gradient boosting REG', gbr))
models.append(('decisiontree REG', dtr))
models.append(('linear REG', lr))

# %%
 #  as random forest in giving the best r2 score  of 92 with a ranom state of 97 
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=97,test_size=.22)
from sklearn.metrics import mean_squared_log_error,mean_absolute_error,mean_squared_error,r2_score
from sklearn.model_selection import cross_val_score

# %%
Model=[]
score=[]
cvs=[]
rocscore=[]
MSE=[]
MAE=[]
RMSE=[]
for name,model in models:
    print('********',name,'*******')
    print('\n')
    Model.append(name)
    model.fit(x_train,y_train)
    print(model)
    pre=model.predict(x_test)
    print('\n')
    R2=r2_score(y_test,pre)
    print("R2_score=",R2)
    score.append(R2*100)
    print('\n')
    sc=cross_val_score(model,x,y,cv=10,scoring='r2').mean()
    print('cross_val_sc=',sc)
    cvs.append(sc*100)
    print('\n')
    mse=mean_squared_error(y_test,pre)
    print('mse',mse)
    MSE.append(mse)
    print('\n')
    mae=mean_absolute_error(y_test,pre)
    print('mae',mae)
    MAE.append(mae)
    print('\n')
    Rmse=np.sqrt(mean_squared_error(y_test,pre))
    print('rmse',Rmse)
    RMSE.append(Rmse)
    print('\n\n')
# Out:
# ******** randomforestREG *******
#
#
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=1000,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False)
#
#
# R2_score= 0.9193130369188682
#
#
# cross_val_sc= 0.9111809776432704
#
#
# mse 0.03318198057092389
#
#
# mae 0.08359807895929046
#
#
# rmse 0.18215921763919576
#
#
#
# ******** kneighborsREG *******
#
#
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=10, p=2,
#                     weights='uniform')
#
#
# R2_score= 0.18598069530714056
#
#
# cross_val_sc= 0.19254068879100777
#
#
# ...

# %%
result=pd.DataFrame({'MODEL':Model,'R2 - SCORE':score,'CROSS_Val_Score':cvs,'MEAN SQ ERROR':MSE,'MEAN ABS ERROR':MAE,'ROOTMEAN SQ ERROR':RMSE})
result
# Out:
#                    MODEL  R2 - SCORE  CROSS_Val_Score  MEAN SQ ERROR  \
# 0        randomforestREG   91.931304        91.118098       0.033182
# 1          kneighborsREG   18.598070        19.254069       0.334760
# 2                    svR   37.663368        35.310936       0.256355
# 3          ada boost REG   87.486985        86.858865       0.051459
# 4  gradient boosting REG   91.362322        90.672208       0.035522
# 5       decisiontree REG   83.659960        82.719856       0.067197
# 6             linear REG   26.594052        26.052789       0.301877
#
#    MEAN ABS ERROR  ROOTMEAN SQ ERROR
# 0        0.083598           0.182159
# 1        0.444022           0.578585
# 2        0.330700           0.506315
# 3        0.157917           0.226846
# 4        0.101723           0.188472
# 5        0.103320           0.259224
# 6        0.426235           0.549433

# %%
y_rfr=rfr.predict(x_test)
plt.scatter(y_test,y_rfr)

# %%
RESULT=pd.DataFrame({'actual':y_test,'predicted':y_rfr})
RESULT.head()
# Out:
#         actual  predicted
# 8770  5.824190   5.809986
# 7262  6.654392   6.610521
# 1832  6.618514   6.856733
# 288   6.697455   6.716299
# 2281  7.355550   7.471867

# %%
## conclusion -- RANDOM FOREST REG (ENSEMBLE METHOD) IS working best for the model , does not contain any underfitting/overfitting
#                in the model with acc and cross val score of >>>>91  and almost linear strainght line graph

# %%
## there fore saving the model
from sklearn.externals import joblib
joblib.dump(rfr,'autoclaim.pkl')
# Out:
# ['autoclaim.pkl']
